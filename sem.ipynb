# %%
ygg = "You are a great teacher!!"

# %% [markdown]
# # Python labs rocks!!

# %% [markdown]
# ### Bitcoin price

# %%
import yfinance as yf

msft = yf.Ticker("BTC-USD")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="max")
hist
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2020-11-30  18178.322266  19749.263672  18178.322266  19625.835938
# 2020-12-01  19633.769531  19845.974609  18321.921875  18802.998047
# 2020-12-02  18801.744141  19308.330078  18347.718750  19201.091797
# 2020-12-03  19205.925781  19566.191406  18925.785156  19445.398438
# 2020-12-04  19257.582031  19501.390625  18748.742188  18953.169922
#
#                  Volume  Dividends  Stock Splits
# Date
# 2014-09-17     21056800          0             0
# 2014-09-18     34483200          0             0
# ...

# %%
pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 5.4 MB 1.4 MB/s eta 0:00:01
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22618 sha256=b0468c50efd57b01809154216913dd6c8207cd95117cb401c56b325837d4e6d7
#   Stored in directory: /home/sem/.cache/pip/wheels/b4/c3/39/9c01ae2b4726f37024bba5592bec868b47a2fab5a786e8979a
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8366 sha256=61125e2b2ffa9b3d746bf89e39f22f8583cd73b06c422f89bb50cca2417234fd
#   Stored in directory: /home/sem/.cache/pip/wheels/57/6d/a3/a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# ...
# Note: you may need to restart the kernel to use updated packages.
